# %%
import pandas as pd

# %%
uclchem_df=pd.read_csv("Benchmarking/high_rad/model_tests.dat")
uclchem_df=uclchem_df[["n_H","x","total_h_col","total_c_col","total_col_dens"]]

# %%
uclchem_df["av"]=uclchem_df["total_col_dens"]*1.6e-21

# %%
uclpdr_df=pd.read_csv("../uclpdr/fort.79")

# %%
uclpdr_df[uclpdr_df.av==2.560000e-07]
# Out:
#                  av           nh2       nc
# 3      2.560000e-07  4.800000e+13      0.0
# 1467   2.560000e-07  2.623140e+08  55578.7
# 2931   2.560000e-07  2.311060e+08  55529.0
# 4393   2.560000e-07  2.311060e+08  55529.0
# 5856   2.560000e-07  2.311060e+08  55529.0
# 7318   2.560000e-07  2.311060e+08  55529.0
# 8781   2.560000e-07  2.576680e+08  66242.1
# 10245  2.560000e-07  2.576680e+08  66242.1
# 11709  2.560000e-07  2.576680e+08  66242.1
# 13172  2.560000e-07  2.576680e+08  66242.1
# 14634  2.560000e-07  2.576680e+08  66242.1
# 16098  2.560000e-07  2.674120e+08  79497.6
# 17562  2.560000e-07  2.674120e+08  79497.6
# 19023  2.560000e-07  2.674120e+08  79497.6
# 20485  2.560000e-07  2.674120e+08  79497.6
# 21949  2.560000e-07  2.674120e+08  79497.6
# 23412  2.560000e-07  2.641860e+08  71932.0
# 24875  2.560000e-07  2.641860e+08  71932.0
# 26418  2.560000e-07  2.641860e+08  71932.0
# 27802  2.560000e-07  2.641860e+08  71932.0
# 29264  2.560000e-07  2.641860e+08  71932.0
# ...

# %%
uclchem_df[uclchem_df.av==2.560000e-07]
# Out:
#       n_H             x  total_h_col  total_c_col  total_col_dens  \
# 0  1000.0 -3.180156e+19  267321600.0     78815.84    1.600000e+14
#
#              av
# 0  2.560000e-07
