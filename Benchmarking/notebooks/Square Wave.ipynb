# %%
import pandas as pd

# %%
uclchem=pd.read_csv("../square/uclchem_outputs.dat")
uclpdr=pd.read_csv("../square/square.prop.out").merge(pd.read_csv("../square/square.av.out"),on="Particle")

# %%
uclpdr.iloc[90:110]
# Out:
#      Particle      n_H           n_g    T_gas   T_dust      chi  F_X  \
# 90         91  10000.0  2.000000e-08  168.465  45.9212  499.962  0.0
# 91         92  10000.0  2.000000e-08  168.465  45.9212  499.962  0.0
# 92         93  10000.0  2.000000e-08  168.465  45.9211  499.958  0.0
# 93         94  10000.0  2.000000e-08  168.464  45.9210  499.954  0.0
# 94         95  10000.0  2.000000e-08  168.464  45.9210  499.950  0.0
# 95         96  10000.0  2.000000e-08  168.463  45.9209  499.946  0.0
# 96         97  10000.0  2.000000e-08  168.463  45.9208  499.942  0.0
# 97         98  10000.0  2.000000e-08  168.462  45.9208  499.938  0.0
# 98         99  10000.0  2.000000e-08  168.462  45.9207  499.935  0.0
# 99        100  10000.0  2.000000e-08  168.462  45.9206  499.931  0.0
# 100       101    100.0  2.000000e-10   10.000  45.9206  499.929  0.0
# 101       102    100.0  2.000000e-10   10.000  45.9206  499.929  0.0
# 102       103    100.0  2.000000e-10   10.000  45.9206  499.929  0.0
# ...

# %%
uclchem.head()
# Out:
#    Unnamed: 0        av  Density  gasTemp  dustTemp      Ly-alpha  \
# 0           0  0.000000  10000.0  168.405     45.87  1.000000e-50
# 1           1  0.000010  10000.0  168.390     45.87  1.000000e-50
# 2           2  0.000018  10000.0  168.375     45.87  1.000000e-50
# 3           3  0.000025  10000.0  168.465     45.87  1.000000e-50
# 4           4  0.000046    100.0  331.720     45.87  1.000000e-50
#
#             C+             O             C            CO   ...     CRheating  \
# 0  1.386251e-20  7.281062e-20  1.794812e-26  1.000000e-50  ...  8.566472e-29
# 1  1.386544e-20  7.291245e-20  1.796232e-26  1.000000e-50  ...  8.571744e-29
# 2  1.386419e-20  7.287742e-20  1.797925e-26  1.000000e-50  ...  8.575334e-29
# 3  1.386207e-20  7.281466e-20  1.000000e-50  1.000000e-50  ...  8.578555e-29
# 4  1.596031e-23  2.217646e-23  1.000000e-50  1.000000e-50  ...  7.799553e-33
#
#     turbHeating   Chemheating  gasGrainColls         H            H2  \
# ...
