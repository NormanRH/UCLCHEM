# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Compare inputs
#
# Load the input to uclchem and the outputs to both codes to see if the correct model was run and what the differences were between the two codes.

# %%
model="10_linear_decrease"
uclchem_in=pd.read_csv(f"../grid_inputs/{model}.csv")
uclchem_out=pd.read_csv(f"../uclchem/{model}.csv")
uclpdr=pd.read_csv(f"../uclpdr/{model}_output.csv")

# %%
uclpdr.head()
# Out:
#    Particle       n_H           n_g       T_g      T_d       FUV  F_x  \
# 0         1  100000.0  2.000000e-07  108.1310  20.9745  10.00000  0.0
# 1         2   99931.7  1.998630e-07   92.8546  20.9744   9.99970  0.0
# 2         3   99863.3  1.997270e-07   90.2764  20.9744   9.99966  0.0
# 3         4   99795.0  1.995900e-07   89.1162  20.9743   9.99964  0.0
# 4         5   99726.7  1.994530e-07   86.9892  20.9743   9.99960  0.0
#
#          Av      H3+_abun      He+_abun  ...  n(o-H2,15)_pop  n(o-H2,16)_pop  \
# 0  0.000000  1.629880e-14  5.151960e-09  ...    0.000000e+00    0.000000e+00
# 1  0.000010  5.296020e-12  2.269630e-09  ...    3.352870e-14    7.709390e-13
# 2  0.000011  6.254840e-12  2.152140e-09  ...    0.000000e+00    0.000000e+00
# 3  0.000012  6.686510e-12  2.106890e-09  ...    0.000000e+00    0.000000e+00
# 4  0.000013  7.445800e-12  2.034310e-09  ...    4.440890e-15    3.339550e-13
#
#    n(o-H2,17)_pop  n(o-H2,18)_pop  n(o-H2,19)_pop  n(o-H2,20)_pop  \
# ...

# %%
uclchem_in.head()
# Out:
#    Particle       T_g       n_H   H2_abun    C_abun     FUV             x  \
# 0         1  108.1310  100000.0  0.012308  0.000003  9.9997 -3.180156e+19
# 1        31   71.9894   97950.1  0.434830  0.000004  9.9997 -3.180156e+19
# 2        61   68.5137   95900.1  0.449782  0.000004  9.9997 -3.180156e+19
# 3        91   67.0683   93850.2  0.455181  0.000004  9.9997 -3.180156e+19
# 4       121   62.8573   91800.3  0.470420  0.000005  9.9997 -3.180155e+19
#
#         delta_x  delta_h2_col   delta_c_col  delta_col_dens  total_h2_col  \
# 0  0.000000e+00  0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
# 1  9.999999e+09  4.259164e+14  4.315191e+09    9.795009e+14  2.223320e+16
# 2  2.000000e+10  8.626827e+14  8.596964e+09    1.918002e+15  4.289206e+16
# 3  2.000000e+10  8.543765e+14  8.388105e+09    1.877004e+15  6.350926e+16
# 4  1.500000e+11  6.477705e+15  6.424263e+10    1.377005e+16  2.629001e+17
#
#     total_c_col  total_col_dens          size
# ...

# %%
uclchem_out.head()
# Out:
#    Unnamed: 0        av   Density  gasTemp  dustTemp      Ly-alpha  \
# 0           0  0.000000  100000.0  108.125     20.95  1.000000e-50
# 1           1  0.000039   97950.0   71.320     20.95  1.000000e-50
# 2           2  0.000068   95900.0   68.010     20.95  1.000000e-50
# 3           3  0.000097   93850.0   66.640     20.95  1.000000e-50
# 4           4  0.000366   91800.0   62.645     20.95  1.000000e-50
#
#             C+             O             C            CO   ...     CRheating  \
# 0  1.287375e-19  1.919680e-18  2.199521e-22  3.020623e-24  ...  1.969341e-24
# 1  9.252079e-20  2.267049e-19  2.889907e-22  3.274789e-23  ...  6.859620e-23
# 2  8.652930e-20  1.744863e-19  2.826859e-22  3.262891e-23  ...  6.913792e-23
# 3  8.284039e-20  1.517470e-19  2.736720e-22  3.185166e-23  ...  6.840279e-23
# 4  7.588696e-20  1.060518e-19  2.722974e-22  3.651323e-23  ...  6.909250e-23
#
#     turbHeating   Chemheating  gasGrainColls         H        H2  \
# ...

# %%
fig,ax=plt.subplots(figsize=(16,9))
ax.plot(uclchem_out["Density"],uclchem_out["gasTemp"],ls="",marker="o")
ax.plot(uclpdr["n_H"],uclpdr["T_g"],ls="",marker="o")
